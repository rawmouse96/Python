# %% [markdown]
# ### 파이썬 시작하기

# %% [markdown]
# #### 1. semi-colon

# %%
# 문장 끝에 세미콜론 붙여도 되지만 붙일필요X 코드라인하나에 여러 실행문 사용시에는 씀
print('Hello')
# Out:
# Hello

# %%
print('hello world'); print("hello world")
# Out:
# hello world
# hello world

# %%
# ,를 사용해도 두개의 문장이 실행되지만 not good method
print('hello world'), print("hello world")
# Out:
# hello world
# hello world
# (None, None)

# %% [markdown]
# #### 2. Comment

# %%
# 한 줄짜리 주석
print('Hello')      #문장 뒤에 와도 됨
# Out:
# Hello

# %%
# 여러줄주석
'''  또는 """ 3개 이후로는 멀티라인 문자열로도 쓰이고, 주석으로도 사용됨
print('Hello')
print('Hello')
print('Hello')
'''
# Out:
# '  또는 """ 3개 이후로는 멀티라인 문자열로도 쓰이고, 주석으로도 사용됨\nprint(\'Hello\')\nprint(\'Hello\')\nprint(\'Hello\')\n'

# %% [markdown]
# #### 3. 들여쓰기

# %%
num = int(input('자연수 입력> '))
if num % 2 == 1:
    print('홀수입니다.')
else:
    print('짝수입니다.')
# Out:
# 홀수입니다.

# %%
a = 10
if a == 10:
    print('10입니다.')
else:
    a = 20
    print('10이 아닙니다.')
# Out:
# 10입니다.

# %% [markdown]
# #### 4. 코드 블록

# %%
if a == 10:
    print('10', end=' ')
    print('입니다.')
# Out:
# 10 입니다.
